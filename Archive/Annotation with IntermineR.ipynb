# %%
source("scripts/functions.R")
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:data.table':
#
#     between, first, last
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
library(InterMineR)
# Out:
# Warning message:
# "multiple methods tables found for 'union'"
# Warning message:
# "multiple methods tables found for 'intersect'"
#
# Attaching package: 'InterMineR'
#
#
# The following objects are masked from 'package:dplyr':
#
#     intersect, union
#
#
# The following objects are masked from 'package:base':
#
#     intersect, union

# %%
im <- initInterMine(mine=listMines()["YeastMine"])
im
# Out:
# An object of class "Service"
# Slot "mine":
#                                     YeastMine
# "https://yeastmine.yeastgenome.org/yeastmine"
#
# Slot "token":
# [1] ""

# %%
template = getTemplates(im)
head(template)
# Out:
#   name                    title
# 1 Genes_Proteins_MolWt    Retrieve-->Proteins in a molecular weight range
# 2 Gene_YeastParalogs      Organism --> All S. cerevisiae Paralogs
# 3 Gene_ChromosomeLocation Gene --> Chromosomal location
# 4 Pathway_Genes           Pathway-->Genes
# 5 Gene_Homologs           Gene --> Non-Fungal and S. cerevisiae Homologs
# 6 DOTerm_DOTermIdentifier DO Term name --> DO Term Identifier

# %%
template[startsWith(template$title, "Chromosomal"),]
# Out:
#    name                      title
# 50 ChromosomeRegion_AllGenes Chromosomal Region --> All genes

# %%
queryRegion = getTemplateQuery(
  im = im, 
  name = "ChromosomeRegion_AllGenes"
)
queryRegion
# Out:
# $model
#      name
# "genomic"
#
# $title
# [1] "Chromosomal Region --> All genes"
#
# $description
# [1] "Retrieve all <a href = \"https://sites.google.com/view/yeastgenome-help/analyze-help/yeastmine\">genes</a> located within the specified chromosome and coordinate range."
#
# $select
#  [1] "Gene.chromosome.primaryIdentifier" "Gene.primaryIdentifier"
#  [3] "Gene.secondaryIdentifier"          "Gene.featureType"
#  [5] "Gene.symbol"                       "Gene.name"
#  [7] "Gene.sgdAlias"                     "Gene.organism.shortName"
#  [9] "Gene.qualifier"                    "Gene.chromosomeLocation.start"
# [11] "Gene.chromosomeLocation.end"       "Gene.chromosomeLocation.strand"
# [13] "Gene.description"
#
# $constraintLogic
# [1] "(A or B) and C and D and E and I"
#
# $name
# [1] "ChromosomeRegion_AllGenes"
#
# $comment
# [1] ""
#
# $orderBy
# $orderBy[[1]]
# Gene.primaryIdentifier
#                  "ASC"
#
#
# $where
# $where[[1]]
# $where[[1]]$path
# [1] "Gene.status"
#
# ...

# %%
resqueryRegion <- runQuery(im, queryRegion)
head(resqueryRegion)
# Out:
#   Gene.chromosome.primaryIdentifier Gene.primaryIdentifier
# 1 chrXIV                            S000005274
# 2 chrXIV                            S000005275
# 3 chrXIV                            S000005276
# 4 chrXIV                            S000005277
# 5 chrXIV                            S000005278
# 6 chrXIV                            S000005279
#   Gene.secondaryIdentifier Gene.featureType Gene.symbol
# 1 YNL330C                  ORF              RPD3
# 2 YNL331C                  ORF              AAD14
# 3 YNL332W                  ORF              THI12
# 4 YNL333W                  ORF              SNZ2
# 5 YNL334C                  ORF              SNO2
# 6 YNL335W                  ORF              DDI2
#   Gene.name
# 1 Reduced Potassium Dependency
# 2 Aryl-Alcohol Dehydrogenase
# 3 THIamine metabolism
# 4 SNooZe
# 5 SNZ proximal Open reading frame
# 6 DNA Damage Inducible
#   Gene.sgdAlias
# 1 histone deacetylase RPD3|MOF6|REC3|SDI2|SDS6
# ...
